# %% [markdown]
# # Árvores de regressão - exercícios 01
#
# Nesta bateria de exercícios, vamos botar em prática o que aprendemos com a base de dados imobiliários de Boston, que pode ser baixada do módulo ```datasets``` do scikitlearn. Essa base de dados possui uma linha por cidade, o objetivo é prever, ou fornecer uma estimativa de ```MEDV```, ou o valor mediano de casas ocupadas pelo dono, dadas as demais variáveis usadas como explicativas.
#
# A descrição das variáveis está abaixo:

# %% [markdown]
# | Variavel | Descrição|
# |-|-|
# |CRIM| taxa de crimes per-cápita da cidade |
# |ZN| proporção de terrenos residenciais zoneados para lotes com mais de 25.000 pés quadrados. |
# |INDUS| proporção de acres de negócios não varejistas por cidade |
# |CHAS |vale 1 se o terreno faz fronteira com o *Charles River*; 0 caso contrário |
# |NOX| Concentração de óxido nítrico (em partes por 10 milhões) |
# |RM| número médio de quartos por habitação |
# |AGE| proporção de unidades ocupadas pelo proprietário construídas antes de 1940 |
# |DIS| distâncias ponderadas até cinco centros de empregos de Boston |
# |RAD| índice de acessibilidade a rodovias radiais |
# |TAX| taxa de imposto sobre a propriedade de valor total por \\$10,000 |
# |PTRATIO| razão pupilo-professor da cidade |
# |B| $ 1000 (Bk - 0,63) ^ 2 $ onde Bk é a proporção de negros por cidade |
# |LSTAT| \%status inferior da população |
# |MEDV| (variável resposta) Valor mediano das casas ocupadas pelo proprietário em US $ 1.000|

# %%
#bibliotecas
import pandas as pd 
import seaborn as sns
import graphviz
import matplotlib.pyplot as plt
# %matplotlib inline
from sklearn import datasets
from sklearn.tree import DecisionTreeRegressor
from sklearn import tree
from sklearn.model_selection import train_test_split


#Separando o Data Frame em variável resposta e variáveis explicativas
boston = datasets.load_boston()
X = pd.DataFrame(boston.data, columns = boston.feature_names)
y = pd.DataFrame(boston.target, columns = ['MEDV'])

# %%
X.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0  0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0
# 1  0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0
# 2  0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0  242.0
# 3  0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0  222.0
# 4  0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0  222.0
#
#    PTRATIO       B  LSTAT
# 0     15.3  396.90   4.98
# 1     17.8  396.90   9.14
# 2     17.8  392.83   4.03
# 3     18.7  394.63   2.94
# 4     18.7  396.90   5.33

# %%
y.head()
# Out:
#    MEDV
# 0  24.0
# 1  21.6
# 2  34.7
# 3  33.4
# 4  36.2

# %% [markdown]
# ### 1. Certifique-se de que esta base está no formato adequado para o scikitlearn.
# ok, essa tarefa é tão fácil que você vai até desconfiar. Mas é preciso ter confiança sobre os dados que se usa ;)

# %%
X.info() #verificando se as variáveis expicativas estão em formato aceitável pela lib sklearn
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 13 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   CRIM     506 non-null    float64
#  1   ZN       506 non-null    float64
#  2   INDUS    506 non-null    float64
#  3   CHAS     506 non-null    float64
#  4   NOX      506 non-null    float64
#  5   RM       506 non-null    float64
#  6   AGE      506 non-null    float64
#  7   DIS      506 non-null    float64
#  8   RAD      506 non-null    float64
#  9   TAX      506 non-null    float64
#  10  PTRATIO  506 non-null    float64
#  11  B        506 non-null    float64
#  12  LSTAT    506 non-null    float64
# dtypes: float64(13)
# memory usage: 51.5 KB

# %% [markdown]
# ### 2.  Visualize a matriz de correlação, e veja se aparentemente você encontra alguma variável com potencial preditivo interessante.

# %%
X_corr = X.copy()
X_corr['MEDV']=y
X_corr.corr()
# Out:
#              CRIM        ZN     INDUS      CHAS       NOX        RM       AGE  \
# CRIM     1.000000 -0.200469  0.406583 -0.055892  0.420972 -0.219247  0.352734
# ZN      -0.200469  1.000000 -0.533828 -0.042697 -0.516604  0.311991 -0.569537
# INDUS    0.406583 -0.533828  1.000000  0.062938  0.763651 -0.391676  0.644779
# CHAS    -0.055892 -0.042697  0.062938  1.000000  0.091203  0.091251  0.086518
# NOX      0.420972 -0.516604  0.763651  0.091203  1.000000 -0.302188  0.731470
# RM      -0.219247  0.311991 -0.391676  0.091251 -0.302188  1.000000 -0.240265
# AGE      0.352734 -0.569537  0.644779  0.086518  0.731470 -0.240265  1.000000
# DIS     -0.379670  0.664408 -0.708027 -0.099176 -0.769230  0.205246 -0.747881
# RAD      0.625505 -0.311948  0.595129 -0.007368  0.611441 -0.209847  0.456022
# TAX      0.582764 -0.314563  0.720760 -0.035587  0.668023 -0.292048  0.506456
# PTRATIO  0.289946 -0.391679  0.383248 -0.121515  0.188933 -0.355501  0.261515
# ...

# %%
cmap = sns.diverging_palette(h_neg=350, h_pos=125, as_cmap=True, sep = 1, center = 'light') # criando configurações do cluster map
sns.clustermap(X_corr.corr(), figsize=(10, 10), center = 0, cmap=cmap) # criando o cluster map

# %% [markdown]
# #### Visando a variável resposta 'MEDV', a variável explicativas 'RM' (quantidade média de quartos) é a que tem a maior correlação positiva. Acompanhada pelas variáveis 'ZN' (proporção de terrenos residenciais zoneados para lotes com mais de 25.000 pés quadrados) e 'B' (Que infelizmente é uma equação que leva em consideração com a proporção de negros por cidade) com uma correlação levemente positiva.
#
# #### Enquanto a variável 'LSTAT' (%status inferior da população) possui uma correlação bem negativa ao preço médio 'MEDV', acompanhada das variáveis 'TAX', 'PTRATIO', 'INDUS','CRIM' (taxa de imposto sobre a propriedade de valor total por 10.000,razão pupilo-professor da cidade, proporção de acres de industrias,taxa de crimes per-cápita da cidade) com uma correlação levemente negativa ao preço medio 'MEDV'.

# %% [markdown]
# ### 3. Separe os dados em validação e teste

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=7777777) #usando o método de treino e teste para separar

# %% [markdown]
# ### 4. Treine duas árvores, uma com profundidade máxima = 8, outra com profundidade máxima = 2.

# %%
#Treinando aárvores de regressão com profundidade de 2 e 8 profundidade
regr_2 = DecisionTreeRegressor(max_depth=2)
regr_8 = DecisionTreeRegressor(max_depth=8)

regr_2.fit(X_train, y_train)
regr_8.fit(X_train, y_train)
# Out:
# DecisionTreeRegressor(max_depth=8)

# %% [markdown]
# ### 5. Calcule o MSE de cada uma das árvores do item anterior para a base de treinamento e para a base de testes.

# %%
#Calculando o erro quadrático para decidir qual melhor árvore

mse1 = regr_2.score(X_train, y_train) # mse1 = mean_squared_error(y_test, regr_2.predict(X_test))

mse2 = regr_8.score(X_train, y_train) # mse2 = mean_squared_error(y_test, regr_8.predict(X_test))

template = "O MSE da árvore com profundidade={0} é: {1:.2f}"

print(template.format(regr_2.get_depth(),mse1).replace(".",","))
print(template.format(regr_8.get_depth(),mse2).replace(".",","))
# Out:
# O MSE da árvore com profundidade=2 é: 0,70
# O MSE da árvore com profundidade=8 é: 0,98

# %% [markdown]
# ### 6. Com base nos resultados do item anterior, qual árvore te parece mais adequada?

# %% [markdown]
# #### O MSE da árvore com profundidade = 8 é mais próximo de 1 levando em conta a fórmula de R² esse modelo explica melhor o fenômeno, com a distância entre os erros médios menores.

# %% [markdown]
# ### 7. Faça uma visualização gráfica dessa árvore. Vamos discutir importância de variável mais adiante, mas veja a sua árvore, e pense um pouco: qual variável te parece mais "importante" na árvore?

# %%
# DOT data
dot_data = tree.export_graphviz(regr_8, out_file=None, 
                                feature_names=X.columns,
                                filled=True)

# Draw graph
plt.rc('figure', figsize=(5, 5))
graph = graphviz.Source(dot_data, format="png") 
plt.savefig('test.png')
graph

# %% [markdown]
# #### A variável 'LSTAT' tem maior importância porque é o nó Raiz
